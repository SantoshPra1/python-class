# %%
a =5
b =2

# %%
a+b
# Out:
# 7

# %%
a*b
# Out:
# 10

# %%
a-b
# Out:
# 3

# %%
a%b  #modulus - remainder
# Out:
# 1

# %%
a/b # real value
# Out:
# 2.5

# %%
a//b # quotient
# Out:
# 2

# %%
a**5
# Out:
# 3125

# %% [markdown]
# assignment operators

# %%
c=76
print(c)
c+=12
print(c)
c-=12
print(c)
c*=5
print(c)
c/=12
print(c)
# Out:
# 76
# 88
# 76
# 380
# 31.666666666666668

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\python class\basics\operator.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/python%20class/basics/operator.ipynb#ch0000011?line=0'>1</a> a!=b
#
# NameError: name 'a' is not defined

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
colors = ['red','blue','green']

# %%
'red' in colors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\python class\basics\operator.ipynb Cell 16' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/python%20class/basics/operator.ipynb#ch0000015?line=0'>1</a> 'red' in colors
#
# NameError: name 'colors' is not defined

# %%
 x = 25
 y = 10
 z = x + y

 the value of x and y is z

 print ('the value of', x , ' and ' , y, 'is', z)
  


sigma = 12.453654
 print(sigma)
# Out:
#   Input In [9]
#     the value of x and y is z
#         ^
# SyntaxError: invalid syntax

# %%
sigma = 12.453654
print(sigma)
# Out:
# 12.453654

# %%
print(x,y,z,x,y,z ,sep ='😍')
# Out:
# 25😍10😍35😍25😍10😍35

# %%
print('hello',end="😃")
print('world',end="😃")
# Out:
# hello😃world😃

# %%
print(1,2,3,4, sep='>>','end'='yay')
# Out:
#   Input In [18]
#     print(1,2,3,4, sep='>>','end'='yay')
#                             ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
name =input("what is your name?")
college =("what college do you go to?")
city =("what city do you live in?")

# %%
print(name, college,city)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\python class\basics\operator.ipynb Cell 23' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/python%20class/basics/operator.ipynb#ch0000024?line=0'>1</a> print(name, college,city)
#
# NameError: name 'name' is not defined

# %%
x = 20
y = 12
z = x+y
print(z)

print('the value of',x,'and',y,'is',z)



print('the value of %d and %d is %d'%(x,y,z))

print('the value of'   +  str(x)  +   'and' +  str(y) +  'is'  +  str(z))


print('the value of {} and {} is {}'.format(x,y,z))
# Out:
# 32
# the value of 20 and 12 is 32
# the value of 20 and 12 is 32
# the value of20and12is32
# the value of 20 and 12 is 32
